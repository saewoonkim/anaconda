# %%
import matplotlib
matplotlib.__version__
import pandas as pd

# %%
import matplotlib.pyplot as plt
x = [2016, 2017, 2018, 2019, 2020]
y = [350,410,520,690,530]

# %%
plt.plot(x,y)
plt.title('Annunal Sale')
plt.xlabel('years')
plt.ylabel('sale')
# Out:
# Text(0, 0.5, 'sale')

# %%
y1 = [350,410,520,695]
y2 = [200,250,385,350]
x = range(len(y1))
x
plt.bar(x, y1, width=0.7, color="blue")
plt.bar(x, y2, width=0.7, color="red", bottom = y1)
plt.title('Quarterly Sale')
plt.xlabel('Quarter')
plt.ylabel('Sales')
xLabel = ['one', 'two', 'three', 'four']
plt.xticks(x, xLabel, fontsize=10)
plt.legend(['chair', 'desks'])

# %% [markdown]
# # 4장 연습문제 7,8번

# %%
df = pd.DataFrame([[500, 450, 520, 610], [690, 700, 820, 900], 
                   [1100, 1030, 1200, 1380], [1500, 1650, 1700, 1850], 
                   [1990, 2020, 2300, 2420], [1020, 1600, 2200, 2550]],
                 index = [2015, 2016, 2017, 2018, 2019, 2020], 
                 columns = ['1분기', '2분기', '3분기', '4분기'])

# %%
df.head(3)
# Out:
#        1분기   2분기   3분기   4분기
# 2015   500   450   520   610
# 2016   690   700   820   900
# 2017  1100  1030  1200  1380

# %%
df.to_csv('C:/Users/ds/Desktop/파이썬/예제/src/chapter_04.csv', header = 'False', encoding = 'utf-8-sig')

# %%
y1 = [500, 450, 520, 610]
y2 = [690, 700, 820, 900]
y3 = [1100, 1030, 1200, 1380]
y4 = [1500, 1650, 1700, 1850]
y5 = [1990, 2020, 2300, 2420]
y6 = [1020, 1600, 2200, 2550]

# %%
x = range(len(y1))
xLabel = ['first','second','third','fourth']

# %%
x
# Out:
# range(0, 4)

# %%
plt.plot(x, y1, color='b')
plt.plot(x, y2, color='orange')
plt.plot(x, y3, color='red')
plt.plot(x, y4, color='green')
plt.plot(x, y5, color='yellow')
plt.plot(x, y6, color='purple')
plt.xlabel('Quarters')
plt.ylabel('Sales')
plt.title('2015-2020 Quarterly Sales')
plt.legend(['2015','2016','2017','2018','2019','2020'])
plt.xticks(x, xLabel, fontsize = 10)
# Out:
# ([<matplotlib.axis.XTick at 0x120cd670450>,
# ...
#  [Text(0, 0, 'first'),
#   Text(1, 0, 'second'),
#   Text(2, 0, 'third'),
#   Text(3, 0, 'fourth')])
