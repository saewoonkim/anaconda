# %% [markdown]
# # 서울시 인구, CCTV 설치 및 범죄 데이터 로드

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cctv = pd.read_excel('C:/Users/ds/Desktop/파이썬/예제/src/cctv/seoul_cctv.xlsx')

# %%
cctv.head(2)
# Out:
#      기관명    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 0  강 남 구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 1  강 동 구  1879     303.0  387.0  134.0     59    144    194    273    385

# %%
cctv.isnull().sum()
#결측치 확인
# Out:
# 기관명         0
# 소계          0
# 2011년 이전    2
# 2012년       2
# 2013년       2
# 2014년       0
# 2015년       0
# 2016년       0
# 2017년       0
# 2018년       0
# dtype: int64

# %%
cctv.fillna(0, inplace=True)
#결측치를 0으로 변경

# %%
cctv.isnull().sum()
# Out:
# 기관명         0
# 소계          0
# 2011년 이전    0
# 2012년       0
# 2013년       0
# 2014년       0
# 2015년       0
# 2016년       0
# 2017년       0
# 2018년       0
# dtype: int64

# %%
cctv.head(2)
# Out:
#      기관명    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 0  강 남 구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 1  강 동 구  1879     303.0  387.0  134.0     59    144    194    273    385

# %%
cctv.rename(columns={cctv.columns[0] : '구청별'}, inplace=True)
#기관명을 구청명으로 변경

# %%
cctv.head(2)
# Out:
#      구청별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 0  강 남 구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 1  강 동 구  1879     303.0  387.0  134.0     59    144    194    273    385

# %%
cctv['2016년 이전'] = cctv['2011년 이전'] + cctv['2012년'] + cctv['2013년'] + cctv['2014년'] + cctv['2015년'] + cctv['2016년']
#2016년 이전 컬럼 생성

# %%
cctv.head(2)
# Out:
#      구청별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0  강 남 구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 1  강 동 구  1879     303.0  387.0  134.0     59    144    194    273    385
#
#    2016년 이전
# 0    4196.0
# 1    1221.0

# %%
cctv.to_excel('C:/Users/ds/Desktop/파이썬/예제/src/cctv/seoul_cctv1.xlsx', index = False)

# %%
cctv_new = cctv.drop(['2011년 이전', '2012년', '2013년','2014년','2015년','2016년'], axis = 1)
#열삭제

# %%
cctv_new.head(2)
# Out:
#      구청별    소계  2017년  2018년  2016년 이전
# 0  강 남 구  5221    577    448    4196.0
# 1  강 동 구  1879    273    385    1221.0

# %%
cctv_new.sort_values(by='소계', ascending=True).head()
# Out:
#         구청별    소계  2017년  2018년  2016년 이전
# 9     도 봉 구   858    117     71     670.0
# 24    중 랑 구  1068     66      9     993.0
# 2     강 북 구  1265      1    319     945.0
# 22    종 로 구  1471    281    101    1089.0
# 23  중     구  1544    317    328     899.0

# %%
cctv_new.sort_values(by='소계', ascending=False).head()
# Out:
#       구청별    소계  2017년  2018년  2016년 이전
# 0   강 남 구  5221    577    448    4196.0
# 4   관 악 구  3985    694    671    2620.0
# 6   구 로 구  3227    540    486    2201.0
# 16  성 북 구  3003    285    643    2075.0
# 21  은 평 구  2962    229    367    2366.0

# %%
popu = pd.read_excel('C:/Users/ds/Desktop/파이썬/예제/src/cctv/seoul_popu.xlsx')

# %%
popu.head(2)
# Out:
#    기간  자치구  세대  인구 인구.1 인구.2 인구.3 인구.4 인구.5   인구.6   인구.7   인구.8  세대당인구  \
# 0  기간  자치구  세대  합계   합계   합계  한국인  한국인  한국인  등록외국인  등록외국인  등록외국인  세대당인구
# 1  기간  자치구  세대   계   남자   여자    계   남자   여자      계     남자     여자  세대당인구
#
#    65세이상고령자
# 0  65세이상고령자
# 1  65세이상고령자

# %%
popu = pd.read_excel('C:/Users/ds/Desktop/파이썬/예제/src/cctv/seoul_popu.xlsx', header = 2, usecols = 'B, D, G, J, N')
#read_excel함수로 열을 선택해서 불러오기

# %%
popu.head()
# Out:
#    자치구         계      계.1     계.2  65세이상고령자
# 0   합계  10049607  9765623  283984   1416131
# 1  종로구    163026   153065    9961     26742
# 2   중구    135633   125725    9908     22005
# 3  용산구    245090   228999   16091     37640
# 4  성동구    316463   308221    8242     42767

# %%
popu.columns = pd.Index(['구청별', '총인구', '한국인', '외국인', '고령자'])

# %%
popu.head(2)
# Out:
#    구청별       총인구      한국인     외국인      고령자
# 0   합계  10049607  9765623  283984  1416131
# 1  종로구    163026   153065    9961    26742

# %%
popu.drop(0, inplace = True)
# 첫 행 삭제 후 적용

# %%
popu.tail()
# Out:
#     구청별     총인구     한국인    외국인    고령자
# 21  관악구  520040  501957  18083  72249
# 22  서초구  438163  433951   4212  54751
# 23  강남구  547453  542364   5089  67085
# 24  송파구  673507  666635   6872  81364
# 25  강동구  431920  427573   4347  58770

# %%
popu.index = pd.Index(np.arange(0,25,1))

# %%
popu.head()
# Out:
#    구청별     총인구     한국인    외국인    고령자
# 0  종로구  163026  153065   9961  26742
# 1   중구  135633  125725   9908  22005
# 2  용산구  245090  228999  16091  37640
# 3  성동구  316463  308221   8242  42767
# 4  광진구  371063  355559  15504  45619

# %%
popu.sort_values(by='외국인', ascending=False).head()
# Out:
#      구청별     총인구     한국인    외국인    고령자
# 18  영등포구  403600  367778  35822  55673
# 16   구로구  438486  404497  33989  61801
# 17   금천구  254021  233917  20104  35739
# 20   관악구  520040  501957  18083  72249
# 5   동대문구  364338  348052  16286  57165

# %%
popu.sort_values(by='고령자', ascending=False).head()
# Out:
#     구청별     총인구     한국인    외국인    고령자
# 23  송파구  673507  666635   6872  81364
# 15  강서구  603611  596949   6662  79660
# 11  은평구  487666  483197   4469  77420
# 10  노원구  548160  543752   4408  77096
# 20  관악구  520040  501957  18083  72249

# %%
pd.merge(popu, cctv_new, on = '구청별')
# Out:
#     구청별     총인구     한국인    외국인    고령자    소계  2017년  2018년  2016년 이전
# 0  동대문구  364338  348052  16286  57165  2003    136    197    1670.0
# 1  서대문구  323080  310313  12767  50456  2121    415    194    1512.0
# 2  영등포구  403600  367778  35822  55673  2495    371    793    1331.0

# %%
# cctv_new 구청별 필드 값 들 공백을 없애기
for df in (popu, cctv_new):
    df['구청별'] = df['구청별'].str.replace(' ', '')

# %%
merged = pd.merge(popu, cctv_new, on = '구청별')

# %%
merged
# Out:
#      구청별     총인구     한국인    외국인    고령자    소계  2017년  2018년  2016년 이전
# 0    종로구  163026  153065   9961  26742  1471    281    101    1089.0
# 1     중구  135633  125725   9908  22005  1544    317    328     899.0
# 2    용산구  245090  228999  16091  37640  2063     60     73    1930.0
# 3    성동구  316463  308221   8242  42767  2679    933    294    1452.0
# 4    광진구  371063  355559  15504  45619  1581    468    346     767.0
# 5   동대문구  364338  348052  16286  57165  2003    136    197    1670.0
# 6    중랑구  408147  403209   4938  61830  1068     66      9     993.0
# 7    성북구  447687  435868  11819  67782  3003    285    643    2075.0
# 8    강북구  322915  319164   3751  58196  1265      1    319     945.0
# 9    도봉구  341649  339413   2236  55964   858    117     71     670.0
# 10   노원구  548160  543752   4408  77096  1906    110    156    1640.0
# 11   은평구  487666  483197   4469  77420  2962    229    367    2366.0
# 12  서대문구  323080  310313  12767  50456  2121    415    194    1512.0
# 13   마포구  386359  375077  11282  50833  1935    372    195    1368.0
# 14   양천구  468145  464185   3960  58045  2775    137    830    1808.0
# 15   강서구  603611  596949   6662  79660  1617    264    254    1099.0
# 16   구로구  438486  404497  33989  61801  3227    540    486    2201.0
# 17   금천구  254021  233917  20104  35739  1634    199    530     905.0
# 18  영등포구  403600  367778  35822  55673  2495    371    793    1331.0
# 19   동작구  409385  396203  13182  59479  1780    278    255    1247.0
# 20   관악구  520040  501957  18083  72249  3985    694    671    2620.0
# 21   서초구  438163  433951   4212  54751  2835    247    396    2192.0
# 22   강남구  547453  542364   5089  67085  5221    577    448    4196.0
# 23   송파구  673507  666635   6872  81364  1586    116    396    1074.0
# 24   강동구  431920  427573   4347  58770  1879    273    385    1221.0

# %%
merged.set_index('구청별', inplace=True)

# %%
merged.head()
# Out:
#         총인구     한국인    외국인    고령자    소계  2017년  2018년  2016년 이전
# 구청별
# 종로구  163026  153065   9961  26742  1471    281    101    1089.0
# 중구   135633  125725   9908  22005  1544    317    328     899.0
# 용산구  245090  228999  16091  37640  2063     60     73    1930.0
# 성동구  316463  308221   8242  42767  2679    933    294    1452.0
# 광진구  371063  355559  15504  45619  1581    468    346     767.0

# %%
merged['1인당cctv비율'] = merged['소계'] / merged['총인구'] * 100

# %%
merged
# Out:
#          총인구     한국인    외국인    고령자    소계  2017년  2018년  2016년 이전  1인당cctv비율
# 구청별
# 종로구   163026  153065   9961  26742  1471    281    101    1089.0   0.902310
# 중구    135633  125725   9908  22005  1544    317    328     899.0   1.138366
# 용산구   245090  228999  16091  37640  2063     60     73    1930.0   0.841732
# 성동구   316463  308221   8242  42767  2679    933    294    1452.0   0.846544
# 광진구   371063  355559  15504  45619  1581    468    346     767.0   0.426073
# 동대문구  364338  348052  16286  57165  2003    136    197    1670.0   0.549764
# 중랑구   408147  403209   4938  61830  1068     66      9     993.0   0.261670
# 성북구   447687  435868  11819  67782  3003    285    643    2075.0   0.670781
# 강북구   322915  319164   3751  58196  1265      1    319     945.0   0.391744
# 도봉구   341649  339413   2236  55964   858    117     71     670.0   0.251135
# 노원구   548160  543752   4408  77096  1906    110    156    1640.0   0.347709
# 은평구   487666  483197   4469  77420  2962    229    367    2366.0   0.607383
# 서대문구  323080  310313  12767  50456  2121    415    194    1512.0   0.656494
# 마포구   386359  375077  11282  50833  1935    372    195    1368.0   0.500830
# 양천구   468145  464185   3960  58045  2775    137    830    1808.0   0.592765
# 강서구   603611  596949   6662  79660  1617    264    254    1099.0   0.267888
# 구로구   438486  404497  33989  61801  3227    540    486    2201.0   0.735941
# 금천구   254021  233917  20104  35739  1634    199    530     905.0   0.643254
# 영등포구  403600  367778  35822  55673  2495    371    793    1331.0   0.618186
# 동작구   409385  396203  13182  59479  1780    278    255    1247.0   0.434799
# 관악구   520040  501957  18083  72249  3985    694    671    2620.0   0.766287
# 서초구   438163  433951   4212  54751  2835    247    396    2192.0   0.647019
# 강남구   547453  542364   5089  67085  5221    577    448    4196.0   0.953689
# 송파구   673507  666635   6872  81364  1586    116    396    1074.0   0.235484
# 강동구   431920  427573   4347  58770  1879    273    385    1221.0   0.435034

# %%
# 서울시 총 cctv 설치 수 대비 총 인구수 상관관계
merged['총인구'].corr(merged['소계'], method = 'pearson')
# Out:
# 0.37523206622060185

# %%
merged['외국인'].corr(merged['소계'], method = 'pearson')
# Out:
# 0.18119377441191767

# %%
merged['고령자'].corr(merged['소계'], method = 'pearson')
# Out:
# 0.29570930426009

# %%
merged['한국인'].corr(merged['소계'], method = 'pearson')
# Out:
# 0.3580254029717922

# %%
# 1인당 CCTV 설치 비율 시각화
sns.countplot(x = '1인당cctv비율',hue='구청별', data=merged)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 2
#       1 # 1인당 CCTV 설치 비율 시각화
# ----> 2 sns.countplot(x = '1인당cctv비율',hue='구청별', data=merged)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1530, in _BarPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1525 def __init__(self, x, y, hue, data, order, hue_order,
#    1526              estimator, errorbar, n_boot, units, seed,
#    1527              orient, color, palette, saturation, width,
#    1528              errcolor, errwidth, capsize, dodge):
#    1529     """Initialize the plotter."""
# -> 1530     self.establish_variables(x, y, hue, data, orient,
#    1531                              order, hue_order, units)
#    1532     self.establish_colors(color, palette, saturation)
#    1533     self.estimate_statistic(estimator, errorbar, n_boot, seed)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:541, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     539     if isinstance(var, str):
#     540         err = f"Could not interpret input '{var}'"
# --> 541         raise ValueError(err)
#     543 # Figure out the plotting orientation
#     544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#
# ValueError: Could not interpret input '구청별'

# %%
from matplotlib import rcParams

# %%
params = {'legend.fontsize' : 14}
plt.rcParams.update(params)
plt.rcParams['xtick.labelsize'] = 14
plt.rcParams['ytick.labelsize'] = 14
plt.close('all')

# %%
#차트에 한글 깨질 경우 한글 스타일 가져오기
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
rc('font', family = font_name)

# %%
#기본 바 차트 그리기
merged['1인당cctv비율'].plot(kind='barh', figsize = (10,7))
# Out:
# <Axes: ylabel='구청별'>

# %%
merged['1인당cctv비율'].sort_values().plot(kind='barh', figsize = (10,7))
# Out:
# <Axes: ylabel='구청별'>

# %%
crime = pd.read_csv('C:/Users/ds/Desktop/파이썬/예제/src/cctv/seoul_crime.csv', sep = '\t')

# %%
crime.head()
# Out:
#      기간  자치구       합계    합계.1   살인 살인.1   강도 강도.1 강간강제추행 강간강제추행.1      절도  \
# 0    기간  자치구       발생      검거   발생   검거   발생   검거     발생       검거      발생
# 1  2018   합계  101,948  74,487  143  139  143  151  6,412    6,046  39,175
# 2  2018  종로구    3,690   3,913    6    7    3    7    236    1,100   1,483
# 3  2018   중구    4,030   2,679    2    2   11   11    207      115   1,855
# 4  2018  용산구    3,411   2,543    1    1    3    2    331      285   1,096
#
#      절도.1      폭력    폭력.1
# 0      검거      발생      검거
# 1  19,762  56,075  48,389
# 2     969   1,962   1,830
# 3     832   1,955   1,719
# 4     522   1,980   1,733

# %%
crime = crime.iloc[2:, 1:4]

# %%
crime.head()
# Out:
#    자치구     합계   합계.1
# 2  종로구  3,690  3,913
# 3   중구  4,030  2,679
# 4  용산구  3,411  2,543
# 5  성동구  2,457  1,787
# 6  광진구  3,915  2,789

# %%
crime.columns = pd.Index(['구청별', '범죄건', '검거건'])

# %%
crime.head()
# Out:
#    구청별    범죄건    검거건
# 2  종로구  3,690  3,913
# 3   중구  4,030  2,679
# 4  용산구  3,411  2,543
# 5  성동구  2,457  1,787
# 6  광진구  3,915  2,789

# %%
crime.set_index('구청별', inplace=True)

# %%
crime.head()
# Out:
#        범죄건    검거건
# 구청별
# 종로구  3,690  3,913
# 중구   4,030  2,679
# 용산구  3,411  2,543
# 성동구  2,457  1,787
# 광진구  3,915  2,789

# %%
crime = crime.apply(lambda x: x.str.replace(',','').apply(pd.to_numeric))

# %%
crime.head()
# Out:
#       범죄건   검거건
# 구청별
# 종로구  3690  3913
# 중구   4030  2679
# 용산구  3411  2543
# 성동구  2457  1787
# 광진구  3915  2789

# %%
crime['검거율'] = crime['검거건'] / crime['범죄건'] * 100

# %%
crime.head()
# Out:
#       범죄건   검거건         검거율
# 구청별
# 종로구  3690  3913  106.043360
# 중구   4030  2679   66.476427
# 용산구  3411  2543   74.552917
# 성동구  2457  1787   72.730973
# 광진구  3915  2789   71.238825

# %%
merged_final = pd.concat([merged, crime], axis = 1)

# %%
merged_final
# Out:
#          총인구     한국인    외국인    고령자    소계  2017년  2018년  2016년 이전  1인당cctv비율  \
# 구청별
# 종로구   163026  153065   9961  26742  1471    281    101    1089.0   0.902310
# 중구    135633  125725   9908  22005  1544    317    328     899.0   1.138366
# 용산구   245090  228999  16091  37640  2063     60     73    1930.0   0.841732
# 성동구   316463  308221   8242  42767  2679    933    294    1452.0   0.846544
# 광진구   371063  355559  15504  45619  1581    468    346     767.0   0.426073
# 동대문구  364338  348052  16286  57165  2003    136    197    1670.0   0.549764
# 중랑구   408147  403209   4938  61830  1068     66      9     993.0   0.261670
# 성북구   447687  435868  11819  67782  3003    285    643    2075.0   0.670781
# 강북구   322915  319164   3751  58196  1265      1    319     945.0   0.391744
# 도봉구   341649  339413   2236  55964   858    117     71     670.0   0.251135
# 노원구   548160  543752   4408  77096  1906    110    156    1640.0   0.347709
# 은평구   487666  483197   4469  77420  2962    229    367    2366.0   0.607383
# 서대문구  323080  310313  12767  50456  2121    415    194    1512.0   0.656494
# 마포구   386359  375077  11282  50833  1935    372    195    1368.0   0.500830
# 양천구   468145  464185   3960  58045  2775    137    830    1808.0   0.592765
# 강서구   603611  596949   6662  79660  1617    264    254    1099.0   0.267888
# 구로구   438486  404497  33989  61801  3227    540    486    2201.0   0.735941
# 금천구   254021  233917  20104  35739  1634    199    530     905.0   0.643254
# 영등포구  403600  367778  35822  55673  2495    371    793    1331.0   0.618186
# 동작구   409385  396203  13182  59479  1780    278    255    1247.0   0.434799
# 관악구   520040  501957  18083  72249  3985    694    671    2620.0   0.766287
# 서초구   438163  433951   4212  54751  2835    247    396    2192.0   0.647019
# 강남구   547453  542364   5089  67085  5221    577    448    4196.0   0.953689
# 송파구   673507  666635   6872  81364  1586    116    396    1074.0   0.235484
# 강동구   431920  427573   4347  58770  1879    273    385    1221.0   0.435034
#
#        범죄건   검거건         검거율
# 구청별
# 종로구   3690  3913  106.043360
# 중구    4030  2679   66.476427
# 용산구   3411  2543   74.552917
# 성동구   2457  1787   72.730973
# 광진구   3915  2789   71.238825
# 동대문구  3680  2968   80.652174
# 중랑구   4288  3222   75.139925
# 성북구   3042  2277   74.852071
# 강북구   3437  2743   79.807972
# 도봉구   2249  1676   74.522010
# 노원구   4007  2725   68.005990
# 은평구   3590  2863   79.749304
# 서대문구  2802  2016   71.948608
# 마포구   5172  3569   69.006187
# 양천구   3515  2459   69.957326
# 강서구   4629  3469   74.940592
# 구로구   4810  3338   69.397089
# 금천구   3293  2567   77.953234
# 영등포구  5840  3922   67.157534
# 동작구   3100  2090   67.419355
# 관악구   5026  3653   72.682053
# 서초구   4726  3183   67.350825
# 강남구   7513  5196   69.160122
# 송파구   5807  4051   69.760634
# 강동구   3919  2789   71.166114
