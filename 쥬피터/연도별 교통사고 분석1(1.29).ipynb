# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ###  데이터 로드

# %%
df2014 = pd.read_csv('C:/Users/ds/Desktop/파이썬/예제/src/2014.csv', encoding='euc-kr')

# %%
df2014.head()
# Out:
#         구분  사고(건)  사망(명)  부상(명)
# 0  2014년1월    169      7    347
# 1  2014년2월    145      3    268
# 2  2014년3월    206     12    358
# 3  2014년4월    182      4    360
# 4  2014년5월    218     17    474

# %%
df2014.shape
# Out:
# (12, 4)

# %%
df2015 = pd.read_csv('C:/Users/ds/Desktop/파이썬/예제/src/2015.csv', encoding='euc-kr')
df2016 = pd.read_csv('C:/Users/ds/Desktop/파이썬/예제/src/2016.csv', encoding='euc-kr')

# %%
df2015.shape
# Out:
# (12, 4)

# %%
df2016.shape
# Out:
# (12, 4)

# %%
df2015.head()
# Out:
#         구분  사고(건)  사망(명)  부상(명)
# 0  2015년1월    205      8    375
# 1  2015년2월    175      8    375
# 2  2015년3월    237      4    492
# 3  2015년4월    227     10    486
# 4  2015년5월    231      9    504

# %%
df2016.head()
# Out:
#         구분  사고(건)  사망(명)  부상(명)
# 0  2016년1월    192      5    387
# 1  2016년2월    174      6    328
# 2  2016년3월    217      7    435
# 3  2016년4월    216      7    419
# 4  2016년5월    239     13    522

# %%
df2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   구분      12 non-null     object
#  1   사고(건)   12 non-null     int64
#  2   사망(명)   12 non-null     int64
#  3   부상(명)   12 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 516.0+ bytes

# %%
merged = pd.concat([df2014, df2015, df2016])

# %%
merged.head()
# Out:
#         구분  사고(건)  사망(명)  부상(명)
# 0  2014년1월    169      7    347
# 1  2014년2월    145      3    268
# 2  2014년3월    206     12    358
# 3  2014년4월    182      4    360
# 4  2014년5월    218     17    474

# %%
merged.tail()
# Out:
#           구분  사고(건)  사망(명)  부상(명)
# 7    2016년8월    230      7    490
# 8    2016년9월    187     13    347
# 9   2016년10월    183     10    367
# 10  2016년11월    200      5    418
# 11  2016년12월    168      4    364

# %%
merged
# Out:
#           구분  사고(건)  사망(명)  부상(명)
# 0    2014년1월    169      7    347
# 1    2014년2월    145      3    268
# 2    2014년3월    206     12    358
# 3    2014년4월    182      4    360
# 4    2014년5월    218     17    474
# 5    2014년6월    233     13    457
# 6    2014년7월    229     14    431
# 7    2014년8월    222      9    447
# 8    2014년9월    225     15    430
# 9   2014년10월    210     14    392
# 10  2014년11월    209     10    386
# 11  2014년12월    178     12    329
# 0    2015년1월    205      8    375
# 1    2015년2월    175      8    375
# 2    2015년3월    237      4    492
# 3    2015년4월    227     10    486
# 4    2015년5월    231      9    504
# 5    2015년6월    207      8    401
# 6    2015년7월    273      7    556
# 7    2015년8월    268     19    534
# 8    2015년9월    252     10    501
# 9   2015년10월    214     14    475
# 10  2015년11월    199      3    398
# 11  2015년12월    213      8    428
# 0    2016년1월    192      5    387
# 1    2016년2월    174      6    328
# ...

# %% [markdown]
# ### 구분 열을 인덱스로 설정

# %%
merged.set_index('구분', inplace = True)

# %%
merged.head()
# Out:
#          사고(건)  사망(명)  부상(명)
# 구분
# 2014년1월    169      7    347
# 2014년2월    145      3    268
# 2014년3월    206     12    358
# 2014년4월    182      4    360
# 2014년5월    218     17    474

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36 entries, 2014년1월 to 2016년12월
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사고(건)   36 non-null     int64
#  1   사망(명)   36 non-null     int64
#  2   부상(명)   36 non-null     int64
# dtypes: int64(3)
# memory usage: 1.1+ KB

# %%
# 데이터 프레임 복사
multy = merged.copy()

# %%
multy.head()
# Out:
#          사고(건)  사망(명)  부상(명)
# 구분
# 2014년1월    169      7    347
# 2014년2월    145      3    268
# 2014년3월    206     12    358
# 2014년4월    182      4    360
# 2014년5월    218     17    474

# %% [markdown]
# ### 년, 월 데이터를 대상으로 인덱스 설정(멀티인덱스)

# %%
from datetime import datetime

# %%
multy.index = pd.to_datetime(multy.index, format='%Y년%m월')

# %%
multy.head()
# Out:
#             사고(건)  사망(명)  부상(명)
# 구분
# 2014-01-01    169      7    347
# 2014-02-01    145      3    268
# 2014-03-01    206     12    358
# 2014-04-01    182      4    360
# 2014-05-01    218     17    474

# %%
multy.set_index([multy.index.year, multy.index.month], inplace = True)

# %%
multy
# Out:
#          사고(건)  사망(명)  부상(명)
# 구분   구분
# 2014 1     169      7    347
#      2     145      3    268
#      3     206     12    358
#      4     182      4    360
#      5     218     17    474
#      6     233     13    457
#      7     229     14    431
#      8     222      9    447
#      9     225     15    430
#      10    210     14    392
#      11    209     10    386
#      12    178     12    329
# 2015 1     205      8    375
#      2     175      8    375
#      3     237      4    492
#      4     227     10    486
#      5     231      9    504
#      6     207      8    401
#      7     273      7    556
#      8     268     19    534
#      9     252     10    501
#      10    214     14    475
#      11    199      3    398
#      12    213      8    428
# 2016 1     192      5    387
#      2     174      6    328
#      3     217      7    435
#      4     216      7    419
#      5     239     13    522
#      6     200     12    362
# ...

# %%
multy.index.names = ['년도','월']

# %%
multy.head()

# %% [markdown]
# ### 년, 월별 사망자 평균

# %%
year = multy.groupby('년도').mean()[['사망(명)']]

# %%
year
# Out:
#           사망(명)
# 년도
# 2014  10.833333
# 2015   9.000000
# 2016   8.166667

# %%
month = multy.groupby('월').mean()[['사망(명)']]

# %%
month
# Out:
#         사망(명)
# 월
# 1    6.666667
# 2    5.666667
# 3    7.666667
# 4    7.000000
# 5   13.000000
# 6   11.000000
# 7   10.000000
# 8   11.666667
# 9   12.666667
# 10  12.666667
# 11   6.000000
# 12   8.000000

# %%
df_2016_d = (multy.loc[2016])['사망(명)'].sum() / (multy.loc[2016])['사고(건)'].sum()

# %%
df_2016_d
# Out:
# 0.04027949034114262

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
multy.loc[2014][['사망(명)', '부상(명)']].plot(kind = 'bar')
# Out:
# <Axes: xlabel='월'>

# %%
(multy.loc[2016,'사망(명)'] - multy.loc[2015,'사망(명)']).nlargest(1, keep='all')
# Out:
# 월
# 5    4
# 6    4
# Name: 사망(명), dtype: int64
